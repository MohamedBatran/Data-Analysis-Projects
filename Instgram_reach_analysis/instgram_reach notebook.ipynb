# %% [markdown]
# - Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import plotly.express as px

# %% [markdown]
# - Import and Get a View in Data

# %%
df = pd.read_csv("Instagram data.csv" , encoding= = 'latin1')

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
df.shape
# Out:
# (119, 13)

# %% [markdown]
# - Data Cleaning

# %%
df.dtypes
# Out:
# Impressions        int64
# From Home          int64
# From Hashtags      int64
# From Explore       int64
# From Other         int64
# Saves              int64
# Comments           int64
# Shares             int64
# Likes              int64
# Profile Visits     int64
# Follows            int64
# Caption           object
# Hashtags          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
df.isna().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.loc[df.duplicated()]
# Out:
#     Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 82         5055       2017           2351           298         108    101
# 83         4002       3401            278           128          73    111
# 84         3169       1979            707           341          32    106
# 85         6168       2177           3450           153         296     82
# 86         2407       1338            655           276          39     40
# 87         3630       1747           1693            72          86    137
# 88         2826       2108            583            76          34     67
# 89         7407       2782           1938          2237         226    288
# 90        10386       4137           3551          2355         205    668
# 91         2998       1945            794            84         139     42
# 92         3052       2608            201           121          87     63
# ...

# %% [markdown]
# - Data Explority (EDA) & Visualization

# %%
df.sample(10)
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 102         4150       1807           1085           463         792     74
# 39          1941       1466            411            37          17     49
# 52          2941       1716           1058            84          48     48
# 47          2826       2108            583            76          34     67
# 82          5055       2017           2351           298         108    101
# 18          6168       2177           3450           153         296     82
# 86          2407       1338            655           276          39     40
# 57          3388       1975           1018           244          44     99
# 38          2191       1308            809            45          18     35
# 36          2327       1774            435            59          35     45
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 102         4       2    145              75       28
# ...

# %%
df.describe().round(1)
# Out:
#        Impressions  From Home  From Hashtags  From Explore  From Other  \
# count        119.0      119.0          119.0         119.0       119.0
# mean        5704.0     2475.8         1887.5        1078.1       171.1
# std         4843.8     1489.4         1884.4        2613.0       289.4
# min         1941.0     1133.0          116.0           0.0         9.0
# 25%         3467.0     1945.0          726.0         157.5        38.0
# 50%         4289.0     2207.0         1278.0         326.0        74.0
# 75%         6138.0     2602.5         2363.5         689.5       196.0
# max        36919.0    13473.0        11817.0       17414.0      2547.0
#
#         Saves  Comments  Shares  Likes  Profile Visits  Follows
# count   119.0     119.0   119.0  119.0           119.0    119.0
# mean    153.3       6.7     9.4  173.8            50.6     20.8
# std     156.3       3.5    10.1   82.4            87.1     40.9
# min      22.0       0.0     0.0   72.0             4.0      0.0
# ...

# %%
plt.figure(figsize=(10, 8))
plt.title("Distribution of Impressions From Home")
sn.distplot(df['From Home'])
plt.show()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_9044\3899892923.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['From Home'])

# %%
plt.figure(figsize=(10, 8))
plt.title("Distribution of Impressions From Hashtags")
sn.distplot(df['From Hashtags'])
plt.show()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_9044\675862151.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['From Hashtags'])

# %%
plt.figure(figsize=(10, 8))
plt.title("Distribution of Impressions From Explore")
sn.distplot(df['From Explore'])
plt.show()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_9044\1754582402.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['From Explore'])

# %%
plt.figure(figsize=(10, 8))
plt.title("Distribution of Impressions From Other")
sn.distplot(df['From Other'])
plt.show()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_9044\2759827138.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['From Other'])

# %%
home = df['From Home'].sum()
explore = df['From Explore'].sum()
hashtags = df['From Hashtags'].sum()
other = df['From Other'].sum()

# %%
labels = ['From Home','From Hashtags','From Explore','From Other']
values = [home , hashtags , explore , other]
fig = px.pie(df , names=labels , values=values , title='Impressions on Instagram Posts From Various Sources', hole=0.5)
fig.show()

# %%
text = ' '.join(i for i in df.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords ,background_color="white").generate(text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud ,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = ' '.join(i for i in df.Hashtags)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords ,background_color="white").generate(text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud ,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
px.scatter(x='Impressions' , y='Likes' , data_frame=df  ,title='Relationship Between Likes and Impressions')

# %%
px.scatter(x='Impressions' , y='Shares' , data_frame=df  ,title='Relationship Between Shares and Impressions')

# %%
px.scatter(x='Impressions' , y='Profile Visits' , data_frame=df  ,title='Relationship Between Profile_visits and Impressions')

# %%
px.scatter(x='Impressions' , y='Saves' , data_frame=df  ,title='Relationship Between Saves and Impressions')

# %%
px.scatter(x='Impressions' , y='Follows' , data_frame=df  ,title='Relationship Between Follows and Impressions')

# %%
px.scatter(x='Impressions' , y='Comments' , data_frame=df  ,title='Relationship Between Comments and Impressions')

# %%
px.scatter(x='Profile Visits' , y='Follows' , data_frame=df ,size='Follows' ,title='Relationship Between Profile_visits and Follows')

# %%
conversion_rate = (df["Follows"].sum() / df["Profile Visits"].sum()) * 100
conversion_rate
# Out:
# 41.00265604249668

# %%
df.corr().round(1)
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_9988\162838519.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                 Impressions  From Home  From Hashtags  From Explore  \
# Impressions             1.0        0.8            0.6           0.9
# From Home               0.8        1.0            0.2           0.8
# From Hashtags           0.6        0.2            1.0           0.2
# From Explore            0.9        0.8            0.2           1.0
# From Other              0.6        0.6            0.2           0.5
# Saves                   0.8        0.8            0.3           0.7
# Comments               -0.0        0.0            0.2          -0.2
# Shares                  0.6        0.7            0.2           0.6
# Likes                   0.8        0.7            0.7           0.7
# ...
