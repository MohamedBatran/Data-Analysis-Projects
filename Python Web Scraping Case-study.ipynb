# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %%
url='https://wuzzuf.net/search/jobs/?q=illustrator&a=hpb'
client=urlopen(url)

# %%
html=client.read()

# %%
client.close()

# %%
soup=bs(html,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
containers=soup.find_all("div",{"class":"css-1gatmva e1v1l3u10"})

# %%
len(containers)
# Out:
# 15

# %%
bs.prettify(containers[0])
# Out:
# '<div class="css-1gatmva e1v1l3u10">\n <style data-emotion="css pkv5jc">\n  .css-pkv5jc{position:relative;min-height:60px;}\n </style>\n <div class="css-pkv5jc">\n  <a href="https://wuzzuf.net/jobs/careers/Movibilecases-Egypt-25235" rel="noreferrer" target="_blank">\n   <style data-emotion="css 17095x3">\n    .css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}\n   </style>\n  </a>\n  <style data-emotion="css laomuu">\n   .css-laomuu{padding-right:60px;}\n  </style>\n  <div class="css-laomuu">\n   <style data-emotion="css m604qf">\n    .css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}\n   </style>\n   <h2 class="css-m604qf">\n    <style data-emotion="css o171kl">\n     .css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}\n    </style>\n    <a class="css-o171kl" href="/jobs/p/bshnqSgXqPx4-Illustrator-Graphic-Dessigner-Mov
# ...

# %%
containers[0].div.h2.text
# Out:
# 'Illustrator & Graphic Dessigner'

# %%
jtitle=containers[0].findAll("h2",{"class":"css-m604qf"})

# %%
jtitle[0].text
# Out:
# 'Illustrator & Graphic Dessigner'

# %%
cname=containers[0].findAll("a",{"class":"css-17s97q8"})

# %%
cname[0].text
# Out:
# 'Movibilecases -'

# %%
jTime=containers[0].findAll("span",{"class":"css-1ve4b75 eoyjyou0"})

# %%
jTime[0].text
# Out:
# 'Full Time'

# %%
f=open("data-wuzzuf-illustrator.csv","w")
header="job_title,company_name,job_time\n"
f.write(header)
# Out:
# 32

# %%
for container in containers:
    jtitle=container.findAll("h2",{"class":"css-m604qf"})
    job_title=jtitle[0].text.strip()

    cname=container.findAll("a",{"class":"css-17s97q8"})
    company_name=cname[0].text.strip()

    cAddress=container.findAll("span",{"class":"css-1ve4b75 eoyjyou0"})
    job_time=jTime[0].text.strip()

    print(job_title)
    print(job_time)
    print(company_name)
    print()
# Out:
# Illustrator & Graphic Dessigner
# Full Time
# Movibilecases -
#
# 2D illustrator / Designer
# Full Time
# Confidential -
#
# 2D Illustrator - Alexandria
# Full Time
# Arabic Localizer -
#
# Motion Graphic Artist
# Full Time
# Pioneers Now -
#
# Graphic Designer
# Full Time
# Shary -
#
# Graphic Designer
# Full Time
# Brandmelon -
#
# Motion Graphic Designer
# Full Time
# Euruq AlSahra -
#
# Graphic Designer ( Alexandria )
# Full Time
# Longman Egypt -
#
# Senior Graphic Designer
# Full Time
# El Megharbel Construction -
#
# Motion Graphics Designer
# Full Time
# CNN Business Arabic -
#
# Graphic Designer
# Full Time
# Longman Egypt -
#
# Interior Designer (Design - Execution)
# Full Time
# MAC EGYPT REAL ESTATE CO. -
#
# Senior Graphic Designer
# Full Time
# Confidential -
#
# Senior Design Architect
# Full Time
# Confidential -
#
# Graphic Design (Static / Motion)
# Full Time
# Confidential -

# %%
f.write(job_title+", "+company_name+", "+job_time+"\n")
f.close()

# %%
import pandas as pd

# %%
df=pd.read_csv('data-wuzzuf-illustrator.csv')

# %%
df
# Out:
#                           job_title     company_name    job_time
# 0  Graphic Design (Static / Motion)   Confidential -   Full Time
# 1  Graphic Design (Static / Motion)   Confidential -   Full Time
# 2  Graphic Design (Static / Motion)   Confidential -   Full Time
# 3  Graphic Design (Static / Motion)   Confidential -   Full Time
# 4  Graphic Design (Static / Motion)   Confidential -   Full Time
