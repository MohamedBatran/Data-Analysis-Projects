# %% [markdown]
# importing packages and data

# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('world_cup_2022_catar.csv')

# %% [markdown]
# exploring and inspecting data

# %%
df.head(4)
# Out:
#                    stage        date   pens pens_home_score pens_away_score  \
# 0                  Final  18/12/2022   True               4               2
# 1  Match for third place  17/12/2022  False           False           False
# 2            Semi-finals  14/12/2022  False           False           False
# 3            Semi-finals  13/12/2022  False           False           False
#
#   team_name_home team_name_away  team_home_score  team_away_score  \
# 0      Argentina         France                3                3
# 1        Croatia        Morocco                2                1
# 2         France        Morocco                2                0
# 3      Argentina        Croatia                3                0
#
#   possession_home  ... duels_won_home  duels_won_away  \
# 0             54%  ...            40%            60%
# 1             51%  ...            53%            47%
# 2             38%  ...            58%            42%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   stage                     64 non-null     object
#  1   date                      64 non-null     object
#  2   pens                      64 non-null     bool
#  3   pens_home_score           64 non-null     object
#  4   pens_away_score           64 non-null     object
#  5   team_name_home            64 non-null     object
#  6   team_name_away            64 non-null     object
#  7   team_home_score           64 non-null     int64
#  8   team_away_score           64 non-null     int64
#  9   possession_home           64 non-null     object
#  10  possession_away           64 non-null     object
#  11  total_shots_home          64 non-null     int64
#  12  total_shots_away          64 non-null     int64
#  13  shots_on_target_home      64 non-null     int64
# ...

# %%
df.describe()
# Out:
#        team_home_score  team_away_score  total_shots_home  total_shots_away  \
# count        64.000000        64.000000         64.000000         64.000000
# mean          1.578125         1.109375         11.296875         11.453125
# std           1.551289         1.055856          5.088673          5.866043
# min           0.000000         0.000000          2.000000          0.000000
# 25%           0.000000         0.000000          8.000000          7.750000
# 50%           1.000000         1.000000         10.500000         10.500000
# 75%           2.000000         2.000000         14.000000         14.000000
# max           7.000000         4.000000         26.000000         32.000000
#
#        shots_on_target_home  shots_on_target_away  prediction_quantity
# count             64.000000             64.000000         6.400000e+01
# mean               4.312500              3.765625         4.036118e+05
# std                2.617857              2.729860         2.001993e+05
# ...

# %%
df['date']=pd.to_datetime(df['date'])
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_17596\1213281828.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   stage                     64 non-null     object
#  1   date                      64 non-null     datetime64[ns]
#  2   pens                      64 non-null     bool
#  3   pens_home_score           64 non-null     object
#  4   pens_away_score           64 non-null     object
#  5   team_name_home            64 non-null     object
#  6   team_name_away            64 non-null     object
#  7   team_home_score           64 non-null     int64
#  8   team_away_score           64 non-null     int64
#  9   possession_home           64 non-null     object
#  10  possession_away           64 non-null     object
#  11  total_shots_home          64 non-null     int64
#  12  total_shots_away          64 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# stage                       0
# date                        0
# pens                        0
# pens_home_score             0
# pens_away_score             0
# team_name_home              0
# team_name_away              0
# team_home_score             0
# team_away_score             0
# possession_home             0
# possession_away             0
# total_shots_home            0
# total_shots_away            0
# shots_on_target_home        0
# shots_on_target_away        0
# duels_won_home              0
# duels_won_away              0
# prediction_team_home_win    0
# prediction_draw             0
# prediction_team_away_win    0
# prediction_quantity         0
# location                    0
# events_list                 0
# lineup_home                 0
# lineup_away                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#                       stage       date   pens pens_home_score pens_away_score  \
# 11              Round of 16 2022-05-12   True               1               3
# 27  Group stage: Matchday 3 2022-11-30  False           False           False
# 17  Group stage: Matchday 3 2022-02-12  False           False           False
# 54  Group stage: Matchday 1 2022-11-23  False           False           False
# 40  Group stage: Matchday 2 2022-11-26  False           False           False
#
#    team_name_home team_name_away  team_home_score  team_away_score  \
# 11          Japan        Croatia                1                1
# 27      Australia        Denmark                1                0
# 17       Cameroon         Brazil                1                0
# 54        Germany          Japan                1                2
# 40      Argentina         Mexico                2                0
#
#    possession_home  ... duels_won_home  duels_won_away  \
# ...

# %%
df.head(3)
# Out:
#                    stage       date   pens pens_home_score pens_away_score  \
# 0                  Final 2022-12-18   True               4               2
# 1  Match for third place 2022-12-17  False           False           False
# 2            Semi-finals 2022-12-14  False           False           False
#
#   team_name_home team_name_away  team_home_score  team_away_score  \
# 0      Argentina         France                3                3
# 1        Croatia        Morocco                2                1
# 2         France        Morocco                2                0
#
#   possession_home  ... duels_won_home  duels_won_away  \
# 0             54%  ...            40%            60%
# 1             51%  ...            53%            47%
# 2             38%  ...            58%            42%
#
#    prediction_team_home_win  prediction_draw  prediction_team_away_win  \
# 0                      64%               3%                       33%
# ...

# %%
df
# Out:
#                       stage       date   pens pens_home_score pens_away_score  \
# 0                     Final 2022-12-18   True               4               2
# 1     Match for third place 2022-12-17  False           False           False
# 2               Semi-finals 2022-12-14  False           False           False
# 3               Semi-finals 2022-12-13  False           False           False
# 4            Quarter-finals 2022-10-12  False           False           False
# ..                      ...        ...    ...             ...             ...
# 59  Group stage: Matchday 1 2022-11-22  False           False           False
# 60  Group stage: Matchday 1 2022-11-21  False           False           False
# 61  Group stage: Matchday 1 2022-11-21  False           False           False
# 62  Group stage: Matchday 1 2022-11-21  False           False           False
# 63  Group stage: Matchday 1 2022-11-20  False           False           False
#
# ...

# %%
df['stage'].nunique()
# Out:
# 8

# %%
df['stage'].unique()
# Out:
# array(['Final', 'Match for third place', 'Semi-finals', 'Quarter-finals',
#        'Round of 16', 'Group stage: Matchday 3',
#        'Group stage: Matchday 2', 'Group stage: Matchday 1'], dtype=object)

# %%
df.corr()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_17596\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           pens  team_home_score  team_away_score  \
# pens                  1.000000        -0.033691         0.080762
# team_home_score      -0.033691         1.000000         0.018927
# team_away_score       0.080762         0.018927         1.000000
# total_shots_home     -0.028650         0.398164         0.123849
# total_shots_away      0.177410        -0.224606         0.291715
# shots_on_target_home -0.057442         0.650537         0.131003
# shots_on_target_away  0.154170        -0.117425         0.504664
# prediction_quantity   0.320803         0.264910        -0.101194
#
#                       total_shots_home  total_shots_away  \
# ...

# %%
plt.bar(df['total_shots_home'],df['team_home_score'])
# Out:
# <BarContainer object of 64 artists>

# %%
df['team_home_score'].sum()+df['team_away_score'].sum()
# Out:
# 172

# %%
df['team_name_home'][df['team_home_score'] > 5].sum()
# Out:
# 'PortugalSpainEngland'

# %%
df['team_name_home'][df['team_away_score'] > 5].sum()
# Out:
# 0

# %%
df['team_name_away']=='Spain'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# Name: team_name_away, Length: 64, dtype: bool

# %%
df.sample(4)
# Out:
#                       stage        date   pens pens_home_score  \
# 62  Group stage: Matchday 1  21/11/2022  False           False
# 40  Group stage: Matchday 2  26/11/2022  False           False
# 9               Round of 16  06/12/2022   True               3
# 51  Group stage: Matchday 1  24/11/2022  False           False
#
#    pens_away_score team_name_home team_name_away  team_home_score  \
# 62           False        England           Iran                6
# 40           False      Argentina         Mexico                2
# 9                0        Morocco          Spain                0
# 51           False    Switzerland       Cameroon                1
#
#     team_away_score possession_home  ... duels_won_home  duels_won_away  \
# 62                2             79%  ...            60%            40%
# 40                0             59%  ...            54%            46%
# 9                 0             23%  ...            55%            45%
# ...

# %%
df[df['stage']=='Final'].value_counts(df['team_home_score'])
# Out:
# team_home_score
# 3    1
# dtype: int64

# %%
df[df['prediction_team_home_win']==df['team_home_score']].count()
# Out:
# stage                       0
# date                        0
# pens                        0
# pens_home_score             0
# pens_away_score             0
# team_name_home              0
# team_name_away              0
# team_home_score             0
# team_away_score             0
# possession_home             0
# possession_away             0
# total_shots_home            0
# total_shots_away            0
# shots_on_target_home        0
# shots_on_target_away        0
# duels_won_home              0
# duels_won_away              0
# prediction_team_home_win    0
# prediction_draw             0
# prediction_team_away_win    0
# prediction_quantity         0
# location                    0
# events_list                 0
# lineup_home                 0
# lineup_away                 0
# dtype: int64

# %%
df['TotalShots']=df['total_shots_away']+df['total_shots_home']

# %%
df['TotalGoals']
# Out:
# 0     6
# 1     3
# 2     2
# 3     3
# 4     3
#      ..
# 59    3
# 60    2
# 61    2
# 62    8
# 63    2
# Name: TotalGoals, Length: 64, dtype: int64

# %%
df['TotalGoals']=df['team_away_score']+df['team_home_score']

# %%
df.head(2)
# Out:
#                    stage        date   pens pens_home_score pens_away_score  \
# 0                  Final  18/12/2022   True               4               2
# 1  Match for third place  17/12/2022  False           False           False
#
#   team_name_home team_name_away  team_home_score  team_away_score  \
# 0      Argentina         France                3                3
# 1        Croatia        Morocco                2                1
#
#   possession_home  ... prediction_team_home_win  prediction_draw  \
# 0             54%  ...                     64%               3%
# 1             51%  ...                     42%               4%
#
#    prediction_team_away_win  prediction_quantity  \
# 0                      33%               1002332
# 1                      54%                367156
#
#                         location  \
# 0          Lusail Iconic Stadium
# 1  Khalifa International Stadium
#
#                                          events_list  \
# ...

# %%
df.to_excel('DataModfied.xlsx')

# %%
df.head(2)
# Out:
#                    stage        date   pens pens_home_score pens_away_score  \
# 0                  Final  18/12/2022   True               4               2
# 1  Match for third place  17/12/2022  False           False           False
#
#   team_name_home team_name_away  team_home_score  team_away_score  \
# 0      Argentina         France                3                3
# 1        Croatia        Morocco                2                1
#
#   possession_home  ... prediction_team_home_win  prediction_draw  \
# 0             54%  ...                     64%               3%
# 1             51%  ...                     42%               4%
#
#    prediction_team_away_win  prediction_quantity  \
# 0                      33%               1002332
# 1                      54%                367156
#
#                         location  \
# 0          Lusail Iconic Stadium
# 1  Khalifa International Stadium
#
#                                          events_list  \
# ...
