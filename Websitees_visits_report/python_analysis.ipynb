# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('df_1.csv')

# %%
df
# Out:
#     Unnamed: 0                Site          Domain Name  \
# 0            0       Google Search           google.com
# 1            1             YouTube          youtube.com
# 2            2            Facebook         facebook.com
# 3            3             Twitter          twitter.com
# 4            4           Instagram        instagram.com
# 5            5               Baidu            baidu.com
# 6            6           Wikipedia        wikipedia.org
# 7            7              Yandex            yandex.ru
# 8            8               Yahoo            yahoo.com
# 9            9             xVideos          xvideos.com
# 10          10            WhatsApp         whatsapp.com
# 11          11             Pornhub          pornhub.com
# 12          12                Xnxx             xnxx.com
# 13          13              Amazon           amazon.com
# 14          14            Yahoo JP          yahoo.co.jp
# 15          15                Live             live.com
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0           Site   Domain Name  \
# 0           0  Google Search    google.com
# 1           1        YouTube   youtube.com
# 2           2       Facebook  facebook.com
#
#                                             Category  \
# 0  Computers Electronics and Technology > Search ...
# 1       Arts & Entertainment > Streaming & Online TV
# 2  Computers Electronics and Technology > Social ...
#
#   Principal country/territory
# 0               United States
# 1               United States
# 2               United States

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   50 non-null     int64
#  1   Site                         50 non-null     object
#  2   Domain Name                  50 non-null     object
#  3   Category                     50 non-null     object
#  4   Principal country/territory  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0
# count    50.00000
# mean     24.50000
# std      14.57738
# min       0.00000
# 25%      12.25000
# 50%      24.50000
# 75%      36.75000
# max      49.00000

# %%
df.sample(5)
# Out:
#     Unnamed: 0      Site   Domain Name  \
# 15          15      Live      live.com
# 30          30   Discord   discord.com
# 22          22   Samsung   samsung.com
# 33          33  Bilibili  bilibili.com
# 25          25  xHamster  xhamster.com
#
#                                              Category  \
# 15       Computers Electronics and Technology > Email
# 30  Computers Electronics and Technology > Social ...
# 22  Computers Electronics and Technology > Consume...
# 33        Arts & Entertainment > Animation and Comics
# 25                                              Adult
#
#    Principal country/territory
# 15               United States
# 30               United States
# 22                 South Korea
# 33                       China
# 25                      Cyprus

# %%
df.rename(columns={'Unnamed: 0':'WebId'},inplace=True)

# %%
df.sample(5)
# Out:
#     Unnamed: 0       Site    Domain Name  \
# 47          47  Stripchat  stripchat.com
# 35          35  Pinterest  pinterest.com
# 3            3    Twitter    twitter.com
# 4            4  Instagram  instagram.com
# 10          10   WhatsApp   whatsapp.com
#
#                                              Category  \
# 47                                              Adult
# 35  Computers Electronics and Technology > Social ...
# 3   Computers Electronics and Technology > Social ...
# 4   Computers Electronics and Technology > Social ...
# 10  Computers Electronics and Technology > Social ...
#
#    Principal country/territory
# 47                      Cyprus
# 35               United States
# 3                United States
# 4                United States
# 10               United States

# %%
df['Site'].unique()
# Out:
# array(['Google Search', 'YouTube', 'Facebook', 'Twitter', 'Instagram',
#        'Baidu', 'Wikipedia', 'Yandex', 'Yahoo', 'xVideos', 'WhatsApp',
#        'Pornhub', 'Xnxx', 'Amazon', 'Yahoo JP', 'Live', 'Netflix',
#        'Reddit', 'TikTok', 'Docomo', 'LinkedIn', 'Office', 'Samsung',
#        'Yandex Turbo Pages', 'VK', 'xHamster', 'Weather', 'Twitch',
#        'Mail.Ru', 'Naver', 'Discord', 'Bing', 'Roblox', 'Bilibili',
#        'Microsoft Online', 'Pinterest', 'Zoom', 'QQ', 'DuckDuckGo',
#        'Microsoft', 'Fandom', 'Quora', 'Yahoo! News', 'RealSRV', 'eBay',
#        'MSN', 'Globo', 'Stripchat', 'Booking', 'OK.ru'], dtype=object)

# %%
df['Site'].nunique()
# Out:
# 50

# %%
df['Site'].value_counts()
# Out:
# Google Search         1
# QQ                    1
# Twitch                1
# Mail.Ru               1
# Naver                 1
# Discord               1
# Bing                  1
# Roblox                1
# Bilibili              1
# Microsoft Online      1
# Pinterest             1
# Zoom                  1
# DuckDuckGo            1
# YouTube               1
# Microsoft             1
# Fandom                1
# Quora                 1
# Yahoo! News           1
# RealSRV               1
# eBay                  1
# MSN                   1
# Globo                 1
# Stripchat             1
# Booking               1
# Weather               1
# xHamster              1
# VK                    1
# Yandex Turbo Pages    1
# Facebook              1
# Twitter               1
# Instagram             1
# Baidu                 1
# Wikipedia             1
# Yandex                1
# Yahoo                 1
# xVideos               1
# WhatsApp              1
# Pornhub               1
# ...

# %%
df['WebId'].nunique()
# Out:
# 50

# %%
df['Domain Name'].nunique()
# Out:
# 50

# %%
df['Domain Name'].unique()
# Out:
# array(['google.com', 'youtube.com', 'facebook.com', 'twitter.com',
#        'instagram.com', 'baidu.com', 'wikipedia.org', 'yandex.ru',
#        'yahoo.com', 'xvideos.com', 'whatsapp.com', 'pornhub.com',
#        'xnxx.com', 'amazon.com', 'yahoo.co.jp', 'live.com', 'netflix.com',
#        'reddit.com', 'tiktok.com', 'docomo.ne.jp', 'linkedin.com',
#        'office.com', 'samsung.com', 'turbopages.org', 'vk.com',
#        'xhamster.com', 'weather.com', 'twitch.tv', 'mail.ru', 'naver.com',
#        'discord.com', 'bing.com', 'roblox.com', 'bilibili.com',
#        'microsoftonline.com', 'pinterest.com', 'zoom.us', 'qq.com',
#        'duckduckgo.com', 'microsoft.com', 'fandom.com', 'quora.com',
#        'news.yahoo.co.jp', 'realsrv.com', 'ebay.com', 'msn.com',
#        'globo.com', 'stripchat.com', 'booking.com', 'ok.ru'], dtype=object)

# %%
df['Domain Name'].value_counts()
# Out:
# google.com             1
# qq.com                 1
# twitch.tv              1
# mail.ru                1
# naver.com              1
# discord.com            1
# bing.com               1
# roblox.com             1
# bilibili.com           1
# microsoftonline.com    1
# pinterest.com          1
# zoom.us                1
# duckduckgo.com         1
# youtube.com            1
# microsoft.com          1
# fandom.com             1
# quora.com              1
# news.yahoo.co.jp       1
# realsrv.com            1
# ebay.com               1
# msn.com                1
# globo.com              1
# stripchat.com          1
# booking.com            1
# weather.com            1
# xhamster.com           1
# vk.com                 1
# turbopages.org         1
# facebook.com           1
# twitter.com            1
# instagram.com          1
# baidu.com              1
# wikipedia.org          1
# yandex.ru              1
# yahoo.com              1
# xvideos.com            1
# whatsapp.com           1
# ...

# %%
df['Principal country/territory'].value_counts()
# Out:
# United States     30
# Russia             5
# China              4
# Japan              2
# South Korea        2
# Cyprus             2
# Czech Republic     1
# Canada             1
# France             1
# Brazil             1
# Netherlands        1
# Name: Principal country/territory, dtype: int64

# %%
df['Principal country/territory'].nunique()
# Out:
# 11

# %%
df['Principal country/territory'].unique()
# Out:
# array(['United States', 'China', 'Russia', 'Czech Republic', 'Canada',
#        'France', 'Japan', 'South Korea', 'Cyprus', 'Brazil',
#        'Netherlands'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Computers Electronics and Technology > Search Engines',
#        'Arts & Entertainment > Streaming & Online TV',
#        'Computers Electronics and Technology > Social Media Networks',
#        'Reference Materials > Dictionaries and Encyclopedias',
#        'News & Media Publishers', 'Adult',
#        'eCommerce & Shopping > Marketplace',
#        'Computers Electronics and Technology > Email',
#        'Computers Electronics and Technology > Telecommunications',
#        'Computers Electronics and Technology > Programming and Developer Software',
#        'Computers Electronics and Technology > Consumer Electronics',
#        'Science and Education > Weather',
#        'Games > Video Games Consoles and Accessories',
#        'Arts & Entertainment > Animation and Comics',
#        'Computers Electronics and Technology > Other Computers Electronics and Technology',
#        'Arts & Entertainment > Other Arts and Entertainment',
# ...

# %%
df['Category'].nunique()
# Out:
# 17

# %%
df['Category'].value_counts()
# Out:
# Computers Electronics and Technology > Social Media Networks                         11
# News & Media Publishers                                                               8
# Adult                                                                                 6
# Computers Electronics and Technology > Search Engines                                 5
# Computers Electronics and Technology > Programming and Developer Software             3
# Reference Materials > Dictionaries and Encyclopedias                                  2
# eCommerce & Shopping > Marketplace                                                    2
# Computers Electronics and Technology > Email                                          2
# Arts & Entertainment > Streaming & Online TV                                          2
# Games > Video Games Consoles and Accessories                                          2
# Arts & Entertainment > Animation and Comics                                           1
# ...

# %%
df.isnull().sum()
# Out:
# WebId                          0
# Site                           0
# Domain Name                    0
# Category                       0
# Principal country/territory    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#     WebId       Site    Domain Name  \
# 1       1    YouTube    youtube.com
# 6       6  Wikipedia  wikipedia.org
# 37     37         QQ         qq.com
# 26     26    Weather    weather.com
# 25     25   xHamster   xhamster.com
#
#                                              Category  \
# 1        Arts & Entertainment > Streaming & Online TV
# 6   Reference Materials > Dictionaries and Encyclo...
# 37                            News & Media Publishers
# 26                    Science and Education > Weather
# 25                                              Adult
#
#    Principal country/territory
# 1                United States
# 6                United States
# 37                       China
# 26               United States
# 25                      Cyprus

# %%
df.to_excel('dataModfied.xlsx')

# %%
data=pd.read_csv('world_cup_2022_catar.csv')

# %%
data.head(4)
# Out:
#                    stage        date   pens pens_home_score pens_away_score  \
# 0                  Final  18/12/2022   True               4               2
# 1  Match for third place  17/12/2022  False           False           False
# 2            Semi-finals  14/12/2022  False           False           False
# 3            Semi-finals  13/12/2022  False           False           False
#
#   team_name_home team_name_away  team_home_score  team_away_score  \
# 0      Argentina         France                3                3
# 1        Croatia        Morocco                2                1
# 2         France        Morocco                2                0
# 3      Argentina        Croatia                3                0
#
#   possession_home  ... duels_won_home  duels_won_away  \
# 0             54%  ...            40%            60%
# 1             51%  ...            53%            47%
# 2             38%  ...            58%            42%
# ...

# %%
data.to_excel('data2.xlsx')
